# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x= input()
# Out:
# 0 2 3 6 9 12 15 18 24 29 39 54 64 74 124

# %%
x= input()
y= input()
x= x.split()
y= y.split()
for i in range(len(x)):
    x[i]=float(x[i])
    y[i]=y[i].replace(',','.')
    y[i]= float(y[i][0:8])
# Out:
# 0 2 4 8 10 15 20 25 30 40 50 60 70 80 125
# -0,003742986279 -0,05372135609 -0,1358468269 -0,3586338084 -0,4383794717 -0,6795415285 -0,898394543 -1,139278629 -1,33649658 -1,790514914 -2,222446595 -2,681021529 -3,133006652 -3,552860498 -5,589742425

# %%
plt.plot(x,y)
plt.grid()
plt.ylabel('ln(V/E)')
plt.xlabel('Tempo(s)')
plt.title('Figura 4: linearização do descarregamento')
plt.show()

# %%
import math as m
def f(x):
    a= (m.e**7.5840)*(m.e**(-0.0030*(x+29.9)**2))
    return a

# %%
h=[]
for i in range(1,24,1):
    c= f(i)
    h.append(c)
print(h)
# Out:
# [112.12003068763075, 92.86715211194272, 76.46017369680561, 62.575260480378454, 50.90545048277923, 41.164243363364, 33.08797753702883, 26.43714423807196, 20.99679905178694, 16.576234285562116, 13.00807085729963, 10.146917857354374, 7.867733275176116, 6.064002132466186, 4.645829799935784, 3.5380297344053404, 2.678267151137976, 2.015303894185473, 1.5073754108477437, 1.1207185028247402, 0.8282584795030211, 0.6084564126096235, 0.4443112271764432]

# %%
plt.plot(x,y)
plt.grid()
plt.ylabel('2V')
plt.xlabel('B*B')
plt.title('Figura 5: 2V x B*B para r=0.05m')
plt.show()

# %%
a= [883/300,607.84/200,234.90/100]
b=[0.16,0.105,0.053]

# %%
# Out:
# [0.16, 0.105, 0.053]

# %%
x= input()
y= input()
x= x.split()
y= y.split()
for i in range(len(x)):
    x[i]=x[i].replace(',','.')
    x[i]=float(x[i])
    y[i]=y[i].replace(',','.')
    y[i]= float(y[i][0:8])
# Out:
# 0,00000140564736 0,000001279161 0,00000117548964 0,000001108809 0,000001028196 0,00000126157824 0,00000092044836 0,000000804609 0,000000804609
# 500 460 420 400 380 360 340 320 300

# %%
x= np.asarray(x)
y=np.asarray(y)
xt= np.matrix.transpose(x)
A= np.matmul(xt,x)
B=np.matmul(xt,y)
alfa= B/A

# %%
alfa= B/A

# %%
alfa
# Out:
# 352743736.76673937

# %%
esm=alfa/0.0025

# %%
print(9**(1/2))
# Out:
# 3.0

# %%
for i in range(len(y)):
    print((esm*y[i])**(1/2))
# Out:
# 8399330.17289759
# 8056354.483578788
# 7698113.260845946
# 7512589.29282563
# 7322366.283418522
# 7127067.987216796
# 6926265.097458843
# 6719464.138318073
# 6506093.175785966
